# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd_data = pd.read_csv('Restaurant_information.csv', encoding='cp949')
print(pd_data.columns)
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_103032\3831128144.py:5: DtypeWarning: Columns (22,27,39,41,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd_data = pd.read_csv('Restaurant_information.csv', encoding='cp949')
# Index(['번호', '개방서비스명', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(x)', '좌표정보(y)',
#        '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총직원수',
#        '본사직원수', '공장사무직직원수', '공장판매직직원수', '공장생산직직원수', '건물소유구분명', '보증액', '월세액',
#        '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지', 'Unnamed: 47'],
#       dtype='object')

# %%
data1 = pd_data['영업상태명']
data2 = pd_data['상세영업상태명']

print(data1.unique())
print('--------------------------')
print(data1.count)

print('=====================================================')

print(data2.unique())
print('--------------------------')
print(data2.count)

print('=====================================================')

data3 = pd_data['인허가일자']
print(data3.unique())
# Out:
# ['폐업' '영업/정상']
# --------------------------
# <bound method Series.count of 0             폐업
# 1             폐업
# 2             폐업
# 3             폐업
# 4             폐업
#            ...
# 2024652    영업/정상
# 2024653    영업/정상
# 2024654    영업/정상
# 2024655    영업/정상
# 2024656    영업/정상
# Name: 영업상태명, Length: 2024657, dtype: object>
# =====================================================
# ['폐업' '영업']
# --------------------------
# <bound method Series.count of 0          폐업
# 1          폐업
# 2          폐업
# 3          폐업
# 4          폐업
#            ..
# 2024652    영업
# 2024653    영업
# 2024654    영업
# 2024655    영업
# 2024656    영업
# Name: 상세영업상태명, Length: 2024657, dtype: object>
# =====================================================
# [20220517 20220527 20220519 ... 20170115 19540328 19991024]

# %%
pd_data2 = pd.read_csv('covid19_data.csv')
print(pd_data2.columns)


c_data1 = pd_data2['New_cases']
print(c_data1)
c_data2 = pd_data2['Country']
print(c_data2)
c_data3 = pd_data2['Date_reported']
print(c_data3)
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 240787    94
# 240788     0
# 240789    49
# 240790    29
# 240791     0
# Name: New_cases, Length: 240792, dtype: int64
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 240787       Zimbabwe
# 240788       Zimbabwe
# 240789       Zimbabwe
# 240790       Zimbabwe
# 240791       Zimbabwe
# Name: Country, Length: 240792, dtype: object
# 0         2020-01-03
# 1         2020-01-04
# 2         2020-01-05
# 3         2020-01-06
# 4         2020-01-07
#              ...
# 240787    2022-10-10
# 240788    2022-10-11
# 240789    2022-10-12
# 240790    2022-10-13
# 240791    2022-10-14
# Name: Date_reported, Length: 240792, dtype: object

# %%
df1= pd.DataFrame(c_data3)
df1['Country']= c_data2
df1['New_cases'] = c_data1
# df1 = df1.reset_index()
# df1.append(c_data2)
# df2 = df1.append(c_data1)

print(df1)
print(df1['Country'].str.contains('Republic of Korea'))

#Republic of Korea
# Out:
#        Date_reported      Country  New_cases
# 0         2020-01-03  Afghanistan          0
# 1         2020-01-04  Afghanistan          0
# 2         2020-01-05  Afghanistan          0
# 3         2020-01-06  Afghanistan          0
# 4         2020-01-07  Afghanistan          0
# ...              ...          ...        ...
# 240787    2022-10-10     Zimbabwe         94
# 240788    2022-10-11     Zimbabwe          0
# 240789    2022-10-12     Zimbabwe         49
# 240790    2022-10-13     Zimbabwe         29
# 240791    2022-10-14     Zimbabwe          0
#
# [240792 rows x 3 columns]
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 240787    False
# 240788    False
# 240789    False
# 240790    False
# 240791    False
# Name: Country, Length: 240792, dtype: bool

# %%
pd_data = pd.read_csv('Delivery service_data.csv', encoding='cp949')
pd_data
# Out:
#     특성별(1)       특성별(2)     특성별(3)                 특성별(4)      2018    2018.1  \
# 0   특성별(1)       특성별(2)     특성별(3)                 특성별(4)       배달앱       배달앱
# 1   특성별(1)       특성별(2)     특성별(3)                 특성별(4)  이용여부 (%)  이용여부 (%)
# 2   특성별(1)       특성별(2)     특성별(3)                 특성별(4)         예       아니오
# 3       전체           소계         소계                     소계       7.6      92.4
# 4      업종별        일반음식점         소계                     소계       6.2      93.8
# 5      업종별        일반음식점         한식                     소계       5.3      94.7
# 6      업종별        일반음식점         중식                     소계      18.7      81.3
# 7      업종별        일반음식점         일식                     소계       3.1      96.9
# 8      업종별        일반음식점        서양식                     소계       6.7      93.3
# 9      업종별        일반음식점     기타 외국식                     소계       4.3      95.7
# 10     업종별      일반음식점 외         소계                     소계       9.3      90.7
# 11     업종별      일반음식점 외   기관 구내식당업                     소계         0       100
# 12     업종별      일반음식점 외  출장·이동음식점업                     소계         0       100
# 13     업종별      일반음식점 외    기타 음식점업                    제과점       1.5      98.5
# 14     업종별      일반음식점 외    기타 음식점업  피자·햄버거·샌드위치 및 유사 음식점업      43.1      56.9
# 15     업종별      일반음식점 외    기타 음식점업                  치킨전문점      45.5      54.5
# 16     업종별      일반음식점 외    기타 음식점업        김밥 및 기타 간이 음식점업       6.4      93.6
# 17     업종별      일반음식점 외    기타 음식점업        간이 음식 포장 판매 전문점       1.7      98.3
# 18     업종별      일반음식점 외        주점업                     소계       2.2      97.8
# 19     업종별      일반음식점 외   비알콜 음료점업                     소계       2.5      97.5
# 20   운영형태별        프랜차이즈         소계                     소계      24.5      75.5
# 21   운영형태별       비프랜차이즈         소계                     소계       4.6      95.4
# 22     지역별          서울권         소계                     소계       5.6      94.4
# 23     지역별          수도권         소계                     소계       8.8      91.2
# 24     지역별          충청권         소계                     소계       6.6      93.4
# 25     지역별          호남권         소계                     소계       4.3      95.7
# 26     지역별          경남권         소계                     소계       8.7      91.3
# 27     지역별          경북권         소계                     소계      10.3      89.7
# 28  매출액규모별      5천만원 미만         소계                     소계       2.2      97.8
# 29  매출액규모별  5천만원~1억원 미만         소계                     소계       5.3      94.7
# 30  매출액규모별   1억원~5억원 미만         소계                     소계       9.7      90.3
# 31  매출액규모별       5억원 이상         소계                     소계       9.8      90.2
#
#         2018.2           2018.3            2018.4       2018.5  ...  \
# 0          배달앱              배달앱               배달앱          배달앱  ...
# 1       월평균 비용           월평균 비용            월평균 비용       월평균 비용  ...
# 2   5만원 미만 (%)  5만원~15만원 미만 (%)  15만원~50만원 미만 (%)  50만원 이상 (%)  ...
# 3          6.9             33.8              48.3         10.7  ...
# 4          5.2             36.8              44.3         13.7  ...
# 5          4.5             32.1              46.6         16.7  ...
# 6            8             49.6              40.5          1.9  ...
# 7         16.3             29.1              30.1         24.5  ...
# 8            0             67.6                24          8.4  ...
# 9            0             25.9              35.1           39  ...
# 10         8.1             31.6              51.3          8.5  ...
# 11           0                0                 0            0  ...
# 12           0                0                 0            0  ...
# 13           0               67                33            0  ...
# 14         9.8             23.7              47.9         16.6  ...
# 15         9.3             27.4              54.2            9  ...
# 16         9.1             66.4              24.5            0  ...
# 17           0             58.5              41.5            0  ...
# 18         2.4             28.1              69.5            0  ...
# 19           0             41.5              58.5            0  ...
# 20         4.8             35.8              47.5         11.4  ...
# 21           9             31.9              49.1           10  ...
# 22         7.7             36.7              44.6         10.9  ...
# 23         9.4             19.4              64.3          5.9  ...
# 24           0             30.2              50.5         19.4  ...
# 25        13.2             39.3              34.2         13.3  ...
# 26         7.1             70.3              20.2          2.4  ...
# 27           4             17.1              58.8         20.2  ...
# 28           0             31.2              21.6         47.2  ...
# 29         7.5               48              44.5            0  ...
# 30         7.5             31.6              50.3         10.6  ...
# 31           0             15.1              52.5         26.9  ...
#
#               2021.4       2021.5    2021.6    2021.7    2021.8      2021.9  \
# 0                배달앱          배달앱       배달앱      배달대행      배달대행        배달대행
# 1             월평균 비용       월평균 비용    월평균 비용  이용여부 (%)  이용여부 (%)      월평균 비용
# 2   15만원~50만원 미만 (%)  50만원 이상 (%)    평균 (원)         예       아니오  5만원 미만 (%)
# 3               36.9           16  272349.6      18.5      81.5         6.4
# 4               38.9         16.1  265250.8      17.5      82.5         6.3
# 5               39.8         16.1  261987.9      15.9      84.1         7.6
# 6               29.9         29.6  395466.6      22.6      77.4         2.5
# 7               40.1         11.4  218219.8      23.5      76.5         3.1
# 8               47.5          6.5  210714.8      28.1      71.9         2.4
# 9               25.6          3.7  134898.4      47.2      52.8           0
# 10              35.2         15.9  278522.1      19.4      80.6         6.6
# 11                 -            -         -         0       100           -
# 12                 0            0     88000       4.6      95.4           0
# 13              39.7            4  169115.2      23.6      76.4         9.2
# 14              38.4         22.4  383686.9      47.2      52.8         4.4
# 15              26.8         26.6  349261.7      45.6      54.4         3.7
# 16              45.1         12.1  267730.7      28.5      71.5         6.6
# 17              24.2         23.9  308978.6      26.6      73.4         6.4
# 18              48.1         15.2  286786.3       4.7      95.3           0
# 19              30.6          4.9  161737.1      17.6      82.4          12
# 20              38.4         17.7  290658.7      37.8      62.2         4.4
# 21                35         13.9    249591      11.5      88.5         8.8
# 22              43.9         19.7  304382.1      18.2      81.8        10.2
# 23              30.1           22  290221.8      16.2      83.8         1.7
# 24              13.1         17.7  241034.3      19.1      80.9         5.3
# 25              65.1          5.4  255146.2      18.6      81.4         2.6
# 26              47.3          5.8  206972.6      24.3      75.7        10.3
# 27              42.7         13.5  329761.5      14.9      85.1           5
# 28              23.3          2.1  159821.5       8.9      91.1        14.9
# 29              40.5            9  229175.9      10.6      89.4        13.2
# 30              36.3           18  280270.1      22.7      77.3         4.5
# 31              44.3         23.1  396119.1      32.9      67.1         5.6
#
#             2021.10           2021.11      2021.12    2021.13
# 0              배달대행              배달대행         배달대행       배달대행
# 1            월평균 비용            월평균 비용       월평균 비용     월평균 비용
# 2   5만원~15만원 미만 (%)  15만원~50만원 미만 (%)  50만원 이상 (%)     평균 (원)
# 3                12              37.3         44.3   902713.5
# 4               9.4              41.2         43.1   828064.4
# 5              10.1              42.4         39.9   758915.1
# 6               2.5              26.8         68.2  1390764.9
# 7               9.5              47.5         39.9  1004186.2
# 8                 4                37         56.5   992869.1
# 9              18.2              47.6         34.2     437541
# 10             14.5              33.6         45.4   974610.8
# 11                -                 -            -          -
# 12                0                 0          100    3000000
# 13             24.7              39.1           27   841295.2
# 14             12.2              26.6         56.7  1684804.2
# 15             15.3              22.9           58  1350476.9
# 16             13.3              38.9         41.2   639736.4
# 17             30.7              39.5         23.4   363757.3
# 18             21.4              42.3         36.3   623469.2
# 19              8.4              39.5           40   656562.9
# 20             10.2              34.3           51  1047554.5
# 21               14              40.8         36.3   733172.4
# 22             18.8              30.4         40.6   907059.1
# 23              8.9              40.1         49.3   961744.9
# 24              6.6                48           40   842071.1
# 25              3.8              53.5         40.1   535409.2
# 26              9.9              28.8           51    1136154
# 27             22.5              34.7         37.8   693056.7
# 28              9.8              27.9         47.4  1058550.3
# 29             14.7              35.2         36.8   935087.2
# 30             11.1              40.2         44.2   787753.4
# 31             17.4              21.6         55.4  1833396.7
#
# [32 rows x 63 columns]
