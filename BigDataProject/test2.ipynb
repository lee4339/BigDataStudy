# %%
import pandas as pd
import numpy as np

delivery_data = pd.read_csv('Delivery_service_data.csv', encoding='cp949')

delivery_data.iloc[:4]

# 필요한 자료
# -배달앱/배달대행 전체 비율(예/아니요)  ---> 이용여부 
# - 년도 2018~ 2021

# 나머지 비용 등의 내용은 필요없음.
# Out:
#    특성별(1)  특성별(2)  특성별(3)  특성별(4)      2018    2018.1      2018.2  \
# 0  특성별(1)  특성별(2)  특성별(3)  특성별(4)       배달앱       배달앱         배달앱
# 1  특성별(1)  특성별(2)  특성별(3)  특성별(4)  이용여부 (%)  이용여부 (%)      월평균 비용
# 2  특성별(1)  특성별(2)  특성별(3)  특성별(4)         예       아니오  5만원 미만 (%)
# 3      전체      소계      소계      소계       7.6      92.4         6.9
#
#             2018.3            2018.4       2018.5  ...            2021.4  \
# 0              배달앱               배달앱          배달앱  ...               배달앱
# 1           월평균 비용            월평균 비용       월평균 비용  ...            월평균 비용
# 2  5만원~15만원 미만 (%)  15만원~50만원 미만 (%)  50만원 이상 (%)  ...  15만원~50만원 미만 (%)
# 3             33.8              48.3         10.7  ...              36.9
#
#         2021.5    2021.6    2021.7    2021.8      2021.9          2021.10  \
# 0          배달앱       배달앱      배달대행      배달대행        배달대행             배달대행
# 1       월평균 비용    월평균 비용  이용여부 (%)  이용여부 (%)      월평균 비용           월평균 비용
# 2  50만원 이상 (%)    평균 (원)         예       아니오  5만원 미만 (%)  5만원~15만원 미만 (%)
# 3           16  272349.6      18.5      81.5         6.4               12
#
#             2021.11      2021.12   2021.13
# 0              배달대행         배달대행      배달대행
# 1            월평균 비용       월평균 비용    월평균 비용
# 2  15만원~50만원 미만 (%)  50만원 이상 (%)    평균 (원)
# 3              37.3         44.3  902713.5
#
# [4 rows x 63 columns]
