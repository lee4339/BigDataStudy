# %%
import sklearn
from sklearn.datasets import load_wine
from sklearn.neighbors import KNeighborsClassifier     
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine = load_wine()
# print(wine['DESCR'])

X, y = load_wine(return_X_y=True)
X = X[:, :2]

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
m = KNeighborsClassifier(n_neighbors=15, weights='distance')
# n_neighbors 최근접 이웃법, weight 영향을 더 많이 받도록 가중치 설정
m.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=15, weights='distance')

# %%
pred = m.predict(X_test)
print('예측값 ', pred)
print('정답 ', y_test)
print('정답비율 ', m.score(X_test, y_test))
# Out:
# 예측값  [0 1 0 0 2 1 0 0 2 0 2 1 1 1 2 1 0 0 2 2 0 2 1 0 0 0 2 1 1 1 2 0 0 1 1 1 1
#  0 0 1 2 0 2 0 1]
# 정답  [0 1 0 0 2 0 0 0 2 0 2 1 1 1 1 1 0 0 1 2 0 2 1 1 0 0 2 2 1 1 2 2 2 1 1 1 1
#  0 1 1 2 0 2 0 1]
# 정답비율  0.8222222222222222

# %%
sns.relplot(x=X[:,0], y=X[:,1], hue=y)
