# %%
from tensorflow import keras

model = keras.models.load_model('cifar10_cnn01.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 159,018
# Trainable params: 159,018
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.weights
# Out:
# [<tf.Variable 'conv2d/kernel:0' shape=(3, 3, 3, 32) dtype=float32, numpy=
#  array([[[[-0.14834219, -0.00169412, -0.0292728 ,  0.05797597,
#             0.0141073 ,  0.02177706,  0.12432494,  0.02678226,
#             0.11973417, -0.20801052, -0.01925809, -0.09775072,
#            -0.16034375,  0.07322684,  0.02471622, -0.18648747,
#            -0.05431635,  0.0893327 , -0.11156897, -0.00530004,
#            -0.00960134, -0.07506748, -0.17671168, -0.08125342,
#            -0.02863406, -0.07390732, -0.10754361,  0.04354548,
#            -0.0793696 , -0.01167967,  0.07421841,  0.19589183],
#           [-0.18638083,  0.10725345, -0.05974538, -0.06750256,
#            -0.10237327,  0.06961812,  0.06747279, -0.15495002,
#             0.01869472, -0.19229452,  0.11779477,  0.0048448 ,
#             0.04469559,  0.09502484,  0.04882476, -0.17072777,
#            -0.02384421, -0.02737186,  0.00494351, -0.01004888,
#            -0.01067864, -0.15309896, -0.00971185,  0.03524423,
# ...

# %%
model.layers[0].weights
# Out:
# [<tf.Variable 'conv2d/kernel:0' shape=(3, 3, 3, 32) dtype=float32, numpy=
#  array([[[[-0.14834219, -0.00169412, -0.0292728 ,  0.05797597,
#             0.0141073 ,  0.02177706,  0.12432494,  0.02678226,
#             0.11973417, -0.20801052, -0.01925809, -0.09775072,
#            -0.16034375,  0.07322684,  0.02471622, -0.18648747,
#            -0.05431635,  0.0893327 , -0.11156897, -0.00530004,
#            -0.00960134, -0.07506748, -0.17671168, -0.08125342,
#            -0.02863406, -0.07390732, -0.10754361,  0.04354548,
#            -0.0793696 , -0.01167967,  0.07421841,  0.19589183],
#           [-0.18638083,  0.10725345, -0.05974538, -0.06750256,
#            -0.10237327,  0.06961812,  0.06747279, -0.15495002,
#             0.01869472, -0.19229452,  0.11779477,  0.0048448 ,
#             0.04469559,  0.09502484,  0.04882476, -0.17072777,
#            -0.02384421, -0.02737186,  0.00494351, -0.01004888,
#            -0.01067864, -0.15309896, -0.00971185,  0.03524423,
# ...
