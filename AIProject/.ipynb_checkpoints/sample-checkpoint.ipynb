# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from tensorflow import keras

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings   #  파이썬 경고메시지 제어
warnings.filterwarnings(action='ignore')

# %%
pd_data = pd.read_csv('시도별_산업별_총괄.csv', encoding='cp949', header=1)
pd_result = pd.DataFrame()

yr_list = [i for i in range(2007, 2020)]
del yr_list[3]

t = [2+x for x in range(8)]
t = [0,1]+t
col_names = pd_data.iloc[:,t].columns

offset = 0
for i, yr in enumerate(yr_list):
    col_list = [2+x+offset for x in range(8)]
    col_list = [0,1] + col_list
    offset = offset+8
    x = pd_data.iloc[:, col_list]
    x.columns = col_names
    x.insert(0, 'year', pd.Series([yr]*72))
    pd_result = pd.concat([pd_result, x], ignore_index=True, axis=0)
    
print(pd_result.shape)
# Out:
# (864, 11)

# %%
filter1 = pd_result['시도별']=='부산광역시'
#print(filter1)
busan = pd_result[filter1]
print(busan.shape)
print(busan)
# Out:
# (48, 11)
#      year    시도별               산업별 기업체수 (개) 종사자수 (명) 급여액 (백만원) 운송수단 및 창고수 (수)  \
# 8    2007  부산광역시  육상운송 및 파이프라인 운송업    25200    85420   1629907          63936
# 9    2007  부산광역시            수상 운송업       87     3036     87602            295
# 10   2007  부산광역시            항공 운송업        -        -         -              -
# 11   2007  부산광역시    창고 및 운송관련 서비스업     3814    15296    350200            346
# 80   2008  부산광역시  육상운송 및 파이프라인 운송업    24840    82246   1553029          59194
# 81   2008  부산광역시            수상 운송업       90     3510    113801            385
# 82   2008  부산광역시            항공 운송업        1      ...       ...            ...
# 83   2008  부산광역시    창고 및 운송관련 서비스업     3100    15231    366975            320
# 152  2009  부산광역시  육상운송 및 파이프라인 운송업    24753    77631   1504525          55758
# 153  2009  부산광역시            수상 운송업      129     4765    160580            533
# 154  2009  부산광역시            항공 운송업        1      ...       ...            ...
# 155  2009  부산광역시    창고 및 운송관련 서비스업     3062    15255    322028            321
# 224  2011  부산광역시  육상운송 및 파이프라인 운송업    25292    72619   1247244          59100
# 225  2011  부산광역시            수상 운송업      114     3990    142306            445
# 226  2011  부산광역시            항공 운송업        1      ...       ...            ...
# 227  2011  부산광역시    창고 및 운송관련 서비스업     2666    12379    292766            308
# 296  2012  부산광역시  육상운송 및 파이프라인 운송업    24630    71792   1424230          58933
# 297  2012  부산광역시            수상 운송업      124     4585    181970            458
# 298  2012  부산광역시            항공 운송업        1      ...       ...            ...
# 299  2012  부산광역시    창고 및 운송관련 서비스업     3040    14876    326687            339
# 368  2013  부산광역시  육상운송 및 파이프라인 운송업    25226    72800   1372123          59030
# 369  2013  부산광역시            수상 운송업      163     4928    193921            588
# 370  2013  부산광역시            항공 운송업        1      ...       ...            ...
# 371  2013  부산광역시    창고 및 운송관련 서비스업     3033    14016    371861            293
# 440  2014  부산광역시  육상운송 및 파이프라인 운송업    25585    72408   1385138          58906
# 441  2014  부산광역시            수상 운송업      158     4485    181880            583
# 442  2014  부산광역시            항공 운송업        1      ...       ...            ...
# 443  2014  부산광역시    창고 및 운송관련 서비스업     3004    15128    397674            332
# 512  2015  부산광역시  육상운송 및 파이프라인 운송업    25823    70803   1455068          56995
# 513  2015  부산광역시            수상 운송업      198     5359    226853            618
# 514  2015  부산광역시            항공 운송업        1      ...       ...            ...
# 515  2015  부산광역시    창고 및 운송관련 서비스업     3026    16325    457937            279
# 584  2016  부산광역시  육상운송 및 파이프라인 운송업    25245    68917   1490703          55117
# 585  2016  부산광역시            수상 운송업      211     5679    254580            697
# 586  2016  부산광역시            항공 운송업        1      ...       ...            ...
# 587  2016  부산광역시    창고 및 운송관련 서비스업     3487    19603    611760            299
# 656  2017  부산광역시  육상운송 및 파이프라인 운송업    25304    69772   1510322          60405
# 657  2017  부산광역시            수상 운송업      191     5521    251882            668
# 658  2017  부산광역시            항공 운송업        1      ...       ...            ...
# 659  2017  부산광역시    창고 및 운송관련 서비스업     4093    21751    743102            350
# 728  2018  부산광역시  육상운송 및 파이프라인 운송업    25459    71896   1574406          58974
# 729  2018  부산광역시            수상 운송업      181     5350    250162            625
# 730  2018  부산광역시            항공 운송업        1        X         X              X
# 731  2018  부산광역시    창고 및 운송관련 서비스업     4088    23304    842364            245
# 800  2019  부산광역시  육상운송 및 파이프라인 운송업    25554    70569   1541693          58085
# 801  2019  부산광역시            수상 운송업      182     5501    259088            618
# 802  2019  부산광역시            항공 운송업        1        X         X              X
# 803  2019  부산광역시    창고 및 운송관련 서비스업     4034    23771    761953            183
#
#     매출액 (백만원) 영업비용 (백만원) 부가가치 (백만원) 유형자산 (백만원)
# 8     5062509    4515307    2864754    5987396
# 9      556389     531819     245297     528758
# 10          -          -          -          -
# 11    1517261    1248246     944072   10752339
# 80    4625980    4191428    2588183    6097921
# 81    1022781     872736     503053    1715054
# 82        ...        ...        ...        ...
# 83    1432543    1243826     879291   11066035
# 152   4765213    4161037    2785599    6317283
# 153   1154478    1060076     580446    1686803
# 154       ...        ...        ...        ...
# 155   1229302    1059116     832019   13453932
# 224   4670504    4300544    2318945    4696239
# 225   1134144    1061298     495116    1897443
# 226       ...        ...        ...        ...
# 227   1720892    1355739    1004863   10236996
# 296   4907452    4546755    2394758    4576540
# 297   1488075    1412812     584525    1923240
# 298       ...        ...        ...        ...
# 299   1536516    1199664     962096    5425295
# 368   4874228    4498778    2431820    4779794
# 369   1698532    1596437     628284    2034604
# 370       ...        ...        ...        ...
# 371   1854084    1485722    1106188    6189300
# 440   5223555    4883241    2465317    4643977
# 441   1736680    1696252     548093    2229390
# 442       ...        ...        ...        ...
# 443   1933154    1505717    1207531    6332842
# 512   4985213    4585313    2444615    4895117
# 513   1917441    1736435     878987    2643489
# 514       ...        ...        ...        ...
# 515   2299789    1904840    1315304    6727425
# 584   4924647    4538562    2531974    6268597
# 585   1800646    1632905     856991    2806929
# 586       ...        ...        ...        ...
# 587   2934910    2401570    1604637    7366865
# 656   4821412    4626648    2557871    4990655
# 657   1782889    1651191     764982    2365420
# 658       ...        ...        ...        ...
# 659   3242521    2673937    1895512    7828300
# 728   4798902    4592965    2531629    5168732
# 729   1583354    1392213     762681    2326265
# 730         X          X          X          X
# 731   3133972    2650012    1882664    7787074
# 800   4784610    4479545    2541258    5111099
# 801   1683880    1586028     721546    2100425
# 802         X          X          X          X
# 803   3171655    2712334    1835358    8616520

# %%
sns.relplot(data=busan, x='year', y='종사자수 (명)', col='산업별', kind='line')

# %%
sns.relplot(data=pd_result[pd_result['시도별']=='인천광역시'], x='year', y='종사자수 (명)', col='산업별', kind='line')
