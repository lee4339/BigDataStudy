# %% [markdown]
# # 전기자동차의 현황과 전기자동차의 전국 충전소위치 데이터 전처리
#
# 출처: https://www.data.go.kr/index.do --> 한국환경공단_전기자동차 충전소 정보, 한국전력공사_지역별 전기차 현황정보
#
# 작성자: 이건호
#
# 배경: 국제적으로 전기차에 대한 관심이 많아지고 우리나라 또한 전기차가 급증함에 따라 예전부터 대두되었던 전기차의 충전소 지역별 분포에 대해 조사하고 지역별 차이가 아직도 많이나는지에 대해 확인하여 부족한 지역이 많은가에 대해 도출하고자함.
#
# 목표: 아래와 같이 전처리된 데이터 확보. pickle 형식으로 저장하여 차후 사용이 용이하도록 함.
# * 전국 각 지역마다 2019년도 부터 2022 초 까지의 데이터를 조사하여 전기차에 대한 증가치
# * 현재 전기차 충전소가 각 지역마다 얼마나 분포되어있는가

# %%
import pickle

#전기자동차 현황 데이터 전처리 부분
with open('한국전력공사_지역별 전기차 현황정보_20220429.csv', 'r', encoding='utf-8') as f:
    cur_raw = f.readlines()

# 데이터 정리
raw_list = []
for line in cur_raw:
    raw_list.append(line[:-1].split(','))

#지역 데이터 축출
area_list = raw_list[0][1:-1]

#날짜 데이터 축출
days_list = [x[0] for x in raw_list[1:]]

#현황 데이터 축출
data_list = [x[1:-1] for x in raw_list[1:]]

for int_data_list in data_list:
    for index, i in enumerate(int_data_list):
        int_data_list[index] = int(i)

# area_list.reverse
print(area_list)        
print(days_list)        
print(data_list)

#전국 전기자동차 충전소위치 데이터 전처리 부분


#데이터 피클 저장
pickle_data = dict()
pickle_data['area'] = area_list
pickle_data['days'] = days_list
pickle_data['data'] = data_list
pickle_data['comment'] = '연도가 증가함에 전기자동차의 댓수가 증가함을 볼 수 있고 각 지역의 충전소를 비교하여 부족한 지역에 대해 조사'

# with open('전기자동차 증가와 충전소 현황.pickle', 'wb') as f:
#     pickle.dump(pickle_data, f)
# Out:
# ['서울', '인천', '경기', '강원', '충북', '충남', '대전', '세종', '경북', '대구', '전북', '전남', '광주', '경남', '부산', '울산', '제주']
# ['2022-03-01', '2022-02-01', '2022-01-01', '2021-12-01', '2021-11-01', '2021-10-01', '2021-09-01', '2021-08-01', '2021-07-01', '2021-06-01', '2021-05-01', '2021-04-01', '2021-03-01', '2021-02-01', '2021-01-01', '2020-12-01', '2020-11-01', '2020-10-01', '2020-09-01', '2020-08-01', '2020-07-01', '2020-06-01', '2020-05-01', '2020-04-01', '2020-03-01', '2020-02-01', '2020-01-01', '2019-12-01', '2019-10-01', '2019-09-01', '2019-08-01', '2019-07-01', '2019-06-01', '2019-05-01', '2019-04-01', '2019-03-01', '2019-02-01', '2019-01-01']
4441, 11641, 2270, 3893, 2660, 4295, 3624, 1650, 18793], [16438, 2791, 12510, 2459, 2457, 2928, 2625, 933, 4161, 11275, 1920, 3346, 2489, 3822, 3270, 1464, 18684], [15353, 2660, 11809, 2448, 2427, 2848, 2618, 911, 4071, 11274, 1872, 3326, 2479, 3634, 3223, 1441, 18307], [14952, 2598, 11750, 2445, 2412, 2841, 2555, 903, 4051, 11313, 1841, 3326, 2464, 3626, 3216, 1447, 18178], [12711, 2412, 11035, 2385, 2271, 2649, 2361, 867, 3832, 9733, 1804, 3278, 2341, 3592, 2645, 1198, 17933], [12389, 2322, 10657, 2339, 2144, 2551, 2303, 857, 3670, 9403, 1752, 3259, 2283, 3458, 2567, 1169, 17779], [12050, 2210, 10304, 2236, 2106, 2490, 2224, 826, 3563, 9053, 1700, 3122, 2213, 3392, 2489, 1123, 17559], [11764, 2132, 9877, 2114, 2074, 2421, 2117, 811, 3409, 8656, 1641, 3077, 2140, 3258, 2410, 1079, 17352], [11082, 1985, 9267, 1945, 1973, 2308, 1937, 800, 3159, 8307, 1586, 2979, 2024, 3108, 2234, 1019, 17101], [10613, 1842, 8549, 1833, 1882, 2246, 1781, 728, 2971, 7964, 1490, 2817, 1870, 3005, 2085, 959, 16588], [10175, 1686, 7872, 1727, 1695, 2051, 1616, 642, 2763, 7475, 1418, 2687, 1736, 2783, 1906, 927, 16066], [9934, 1499, 7290, 1567, 1377, 1559, 1463, 535, 2404, 7140, 1196, 2514, 1587, 2602, 1786, 902, 15597], [9647, 1341, 6579, 1423, 1216, 1161, 1358, 414, 2043, 6927, 1017, 1999, 1462, 2211, 1602, 864, 15268], [9571 ...

# %%
import requests

url = 'http://apis.data.go.kr/B552584/EvCharger/getChargerInfo'
s_key = 'Oc+0oEXikbOn8irQ007JmQedWhaRAR+Z1ZMGmyDUeBwbvv8GIJgssZL0tVHpSwkmI2uuPRNz4vTIzPgFeBj3/Q=='
params ={'serviceKey' : s_key, 'pageNo' : '1', 'numOfRows' : '9999'}

response = requests.get(url, params=params)

# %%
adr_raw = response.content.decode('utf-8')
#print(adr_raw)

addr1, addr2 = 0, 0
addr_list = []
while True:
        addr1 = adr_raw.find('<addr>', addr2)
        if addr1 == -1:
            break
            
        addr1 += len('<addr>')
        addr2 = adr_raw.find('</addr>', addr1)
        addr_list.append(adr_raw[addr1:addr2])
    

#print(addr_list)

# %%
addr_list2 = []
addr_list3 = []

for i in addr_list:
    addr_list2.append(i.split(' '))

#print(addr_list2)

for j in addr_list2:
    addr_list3.append(j[0])
    
print(addr_list3)
# Out:
# ['서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '대구광역시', '대구광역시', '대구광역시', '대구광역시', '대구광역시', '대구광역시', '대구광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '광주광역시', '광주광역시', '광주광역시', '대전광역시', '대전광역시', '울산광역시', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '강원도', '강원도', '강원도', '강원도', '강원도', '강원도', '강원도', '강원도', '강원도', '강원도', '강원도', '강원도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라남도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라북도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '전라남도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '경상남도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '세종특별자치시', '세종특별자치시', '세종특별자치시', '제주특별자치도', '제주특별자치도', '제주특별자치도', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '서울특별시', '', '', '서울특별시', '서울특별시', '서울특별시', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '제주특별자치도', '전라남도', '전라남도', '전라남도', '전라남도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '강원도', '강원도', '강원도', '강원도', '강원도', '강원도', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '부산광역시', '대구광역시', '충청남도', '충청남도', '충청북도', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '인천광역시', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '경기도', '대전광역시', '대전광역시', '대전광역시', '대전광역시', '대전광역시', '대전광역시', '대전광역시', '대전광역시', '대전광역시', '경상북도', '경기도', '경기도', '경기도', '경기도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '경상북도', '대전광역시', '서울특별시', '서울특별시', '충청남도', '충청남도', '충청남도', '충청남도', '충청남도', '충청북도', '충청북도', '충청북도', '경상남도', '경상남도', '경상남도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '충청북도', '전라남도 ...

# %%
set_list3 = list(set(addr_list3)) 
print(set_list3)
one_list = []
for item in set_list3:
    if item == '' or item == '97-32' or item == '제일오투마트' or item == '5층' or item == 'null' or item == '지상' or item == ',':
        pass
    else:
        one_list.append(item)
print(one_list)
# Out:
# ['', '97-32', '제주특별자치도', '전라남도', '부산광역시', '서울특별시', '강원도', '제일오투마트', '5층', '광주광역시', '세종특별자치시', '충청남도', '충청북도', '인천광역시', '울산광역시', '경상북도', '전라북도', ',', 'null', '경상남도', '대구광역시', '경기도', '대전광역시', '지상']
# ['제주특별자치도', '전라남도', '부산광역시', '서울특별시', '강원도', '광주광역시', '세종특별자치시', '충청남도', '충청북도', '인천광역시', '울산광역시', '경상북도', '전라북도', '경상남도', '대구광역시', '경기도', '대전광역시']
