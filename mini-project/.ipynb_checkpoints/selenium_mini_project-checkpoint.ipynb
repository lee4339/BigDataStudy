# %%
# 전기자동차 각 지역별 댓수와 충전소 위치 대칭 selenium으로 도전해보기
import requests

url = 'http://apis.data.go.kr/B552584/EvCharger/getChargerInfo'
s_key = 'Oc+0oEXikbOn8irQ007JmQedWhaRAR+Z1ZMGmyDUeBwbvv8GIJgssZL0tVHpSwkmI2uuPRNz4vTIzPgFeBj3/Q=='
params ={'serviceKey' : s_key, 'pageNo' : '1', 'numOfRows' : '9999'}

response = requests.get(url, params=params)
adr_raw = response.content.decode('utf-8')
print(adr_raw[:9999])
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg><totalCount>134948</totalCount><pageNo>1</pageNo><numOfRows>9999</numOfRows></header><body><items><item><statNm>종묘 공영주차장</statNm><statId>ME000001</statId><chgerId>01</chgerId><chgerType>03</chgerType><addr>서울특별시 종로구 종로 157</addr><location>null</location><lat>37.571076</lat><lng>126.99588</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20220316144310</statUpdDt><lastTsdt>20211028002722</lastTsdt><lastTedt>20211028004608</lastTedt><nowTsdt></nowTsdt><powerType></powerType><output>50</output><method>단독</method><zcode>11</zcode><zscode>11110</zscode><kind>B0</kind><kindDetail>B001</kindDetail><parkingFree>Y</parkingFree><note></note><limitYn>N</limitYn><limitDetail></limitDetail><delYn>N</delYn><delDetail></delDetail></item><item><statNm>세종로 공영주차장</statNm><statId>ME000002</statId><chgerId>01</chgerId><chgerType>06</chgerType><addr>서울특별시 종로구 세종대로 189</addr><location>null</location><lat>37.573611</lat><lng>126.976011</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20210831224310</statUpdDt><lastTsdt>20210826023834</lastTsdt><lastTedt>20210826030435</lastTedt><nowTsdt></nowTsdt><powerType></powerType><output>50</output><method>단독</method><zcode>11</zcode><zscode>11110</zscode><kind>B0</kind><kindDetail>B001</kindDetail><parkingFree>Y</parkingFree><note></note><limitYn>N</limitYn><limitDetail></limitDetail><delYn>N</delYn><delDetail></delDetail></item><item><statNm>그랜드앰배서더 서울</statNm><statId>ME000003</statId><chgerId>01</chgerId><chgerType>06</chgerType><addr>서울특별시 중구 동호로 287</addr><location>null</location><lat>37.559352</lat><lng>127.002350</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20210910103310</statUpdDt><lastTsdt>20210905214809</lastTsdt><lastTedt>20210905221814</lastTedt><nowTsdt></nowTsdt><powerType></powerType><output>50</output><method>단독</method><zcode>11</zcode><zscode>11140</zscode><kind>E0</kind><kindDetail>E003</kindDetail><parkingFree>N</parkingFree><note></note><limitYn>N</limitYn><limitDetail></limitDetail><delYn>N</delYn><delDetail></delDetail></item><item><statNm>한강진역 공영주차장</statNm><statId>ME000004</statId><chgerId>01</chgerId><chgerType>03</chgerType><addr>서울특별시 용산구 한남동 산10-84</addr><location>null</location><lat>37.540085</lat><lng>127.002804</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20210910095310</statUpdDt><lastTsdt>20210903090537</lastTsdt><lastTedt>20210903093530</lastTedt><nowTsdt></nowTsdt><powerType></powerType><output>50</output><method>단독</method><zcode>11</zcode><zscode>11170</zscode><kind>B0</kind><kindDetail>B001</kindDetail><parkingFree>Y</parkingFree><note></note><limitYn>N</limitYn><limitDetail></limitDetail><delYn>N</delYn><delDetail></delDetail></item><item><statNm>마장동사무소 앞(공중전화부스)</statNm><statId>ME000006</statId><chgerId>01</chgerId><chgerType>06</chgerType><addr>서울특별시 성동구 마장동 808</addr><location>null</location><lat>37.5660935</lat><lng>127.0455256</lng><useTime>24시간 이용가능</useTime><busiId>ME</busiId><bnm>환경부</bnm><busiNm>환경부</busiNm><busiCall>1661-9408</busiCall><stat>9</stat><statUpdDt>20220825184810</statUpdDt><lastTsdt>20220811085917</lastTsdt><lastTedt>20220811092106</lastTedt><nowTsdt></nowTsdt><powerType></powerType><output>50</output><method>단독</method><zcode>11</zcode><zscode>11200</zscode><kind>G0</kind><kindDetail>G003</kindDetail><parkingFree>N</parkingFree><note></note><limitYn>N</limitYn><limitDetail></limitDetail><delYn>N</delYn><delDetail></delDetail></item><item><statNm>청량리롯데백화점</statNm><statId>ME000007</statId><chgerId>01</chgerId><chgerType>03</chgerType><addr>서울특별시 ...
