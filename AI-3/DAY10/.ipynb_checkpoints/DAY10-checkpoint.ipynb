# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = sns.load_dataset('tips')
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(df)

# %%
fig = plt.figure(figsize=[12,4])
a = fig.add_subplot(1,2,1)
sns.scatterplot(data=df, x='day', y='total_bill', ax=a)
b = fig.add_subplot(1,2,2)
sns.histplot(data=df, x='day', y='total_bill', ax=b, cbar=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
fig = plt.figure(figsize=[12,4])
a = fig.add_subplot(1,2,1)
# sns.stripplot(data=df, x='day', y='total_bill', ax=a, jitter=0.2)  # jitter : 폭
sns.stripplot(data=df, x='day', y='total_bill', ax=a, jitter=0.2, hue='sex', legend=False, dodge=True)

b = fig.add_subplot(1,2,2)
sns.swarmplot(data=df, x='day', y='total_bill', ax=b, hue='sex', dodge=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
fig = plt.figure(figsize=[20,4])
a = fig.add_subplot(1,3,1)
sns.boxplot(data=df, x='day', y='total_bill', ax=a, hue='sex')

b = fig.add_subplot(1,3,2)
sns.violinplot(data=df, x='day', y='total_bill', ax=b, bw=0.5, cut=0)

c = fig.add_subplot(1,3,3)
sns.boxenplot(data=df, x='day', y='total_bill', ax=c)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
# sns.catplot(data=df, x='day', y='total_bill', kind='box')
# sns.catplot(data=df, x='day', y='total_bill', kind='violin', hue='sex', split=True, inner='point')

# %%
fig = plt.figure(figsize=[20,4])
a = fig.add_subplot(1,3,1)
a.set_ylim(0, 25)
sns.barplot(data=df, x='day', y='total_bill', ax=a, hue='sex')

b = fig.add_subplot(1,3,2)
b.set_ylim(0, 25)
sns.pointplot(data=df, x='day', y='total_bill', ax=b, hue='sex', dodge=True)

c = fig.add_subplot(1,3,3)
sns.countplot(data=df, x='day', ax=c)
# Out:
# <AxesSubplot: xlabel='day', ylabel='count'>

# %%
fig = plt.figure(figsize=[12,4])
a = fig.add_subplot(1,2,1)
sns.countplot(data=df, x='day', ax=a)

b = fig.add_subplot(1,2,2)
sns.histplot(data=df, x='day', ax=b, shrink=0.7)
# Out:
# <AxesSubplot: xlabel='day', ylabel='Count'>

# %%
df1 = sns.load_dataset('flights')
# print(df1)
df2 = df1.pivot(index='month', columns='year', values='passengers')
# print(df2)
# sns.heatmap(df2, annot=True, fmt='d')
sns.heatmap(df2)
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>

# %%
a = df[['day','time','tip']].dropna()
print(a)
b = a.groupby(['day', 'time']).sum()
b = b.reset_index()
print(b)

c = b.pivot('time','day','tip')
sns.heatmap(c, annot=True, fmt='g')

# sns.heatmap(a)
# Out:
#       day    time   tip
# 0     Sun  Dinner  1.01
# 1     Sun  Dinner  1.66
# 2     Sun  Dinner  3.50
# 3     Sun  Dinner  3.31
# 4     Sun  Dinner  3.61
# ..    ...     ...   ...
# 239   Sat  Dinner  5.92
# 240   Sat  Dinner  2.00
# 241   Sat  Dinner  2.00
# 242   Sat  Dinner  1.75
# 243  Thur  Dinner  3.00
#
# [244 rows x 3 columns]
#     day    time     tip
# 0  Thur   Lunch  168.83
# 1  Thur  Dinner    3.00
# 2   Fri   Lunch   16.68
# 3   Fri  Dinner   35.28
# 4   Sat   Lunch    0.00
# 5   Sat  Dinner  260.40
# 6   Sun   Lunch    0.00
# 7   Sun  Dinner  247.39
# <AxesSubplot: xlabel='day', ylabel='time'>

# %%
fig = plt.figure(figsize=[12,4])
a= fig.add_subplot(1,2,1)
sns.regplot(data=df, x='total_bill', y='tip')
b= fig.add_subplot(1,2,2)
sns.residplot(data=df, x='total_bill', y='tip')

sns.lmplot(data=df, x='total_bill', y='tip')    #fig level
