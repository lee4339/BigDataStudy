# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import matplotlib as mp
npr = np.random

# %%
xs = np.linspace(0, 50, 100)
ys = np.sin(xs)

# %%
plt.plot(xs, ys)

# %%
fig, axe = plt.subplots()
axe.plot(xs, ys)
print(type(fig))
print(type(axe))
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
# figure : 도화지
fig1 = mp.figure.Figure(figsize=[12, 8])
fig2 = plt.figure(figsize=[6, 4])
print(fig1)

a = fig2.add_axes([0, 0, 1, 1])
print(type(a))
b = fig2.add_axes([0, 0, 0.5, 0.5])

c = fig2.add_axes([0.1, 0.1, 0.3, 0.3])
a.plot(xs, ys)

fig2.suptitle('myfirst plot')
fig2.supxlabel('X LABEL')
fig2.supylabel('Y LABEL')
fig2.set_facecolor('blue')
fig2.text(0.5, 0.5, 'my text')
# Out:
# Figure(864x576)
# <class 'matplotlib.axes._axes.Axes'>
# Text(0.5, 0.5, 'my text')

# %%
fig3, axe = plt.subplots(3,2, tight_layout=True, sharey=True)
print(fig3)
print(type(axe))
axe[1, 1].plot(xs, ys)
# Out:
# Figure(432x288)
# <class 'numpy.ndarray'>

# %%
fig4 = plt.figure()
a = fig4.add_subplot(2, 1, 1)
b = fig4.add_subplot(3, 3, 5)
c = fig4.add_subplot(2, 2, 4)

# %%
fig5 = plt.figure(tight_layout=True)
print(fig5)

a = fig5.add_subplot(3, 2, 1)
fig5.add_subplot(3, 2, 2)
fig5.add_subplot(3, 1, 2)
fig5.add_subplot(3, 2, 5)
fig5.add_subplot(3, 2, 6)

print(fig5)
print(fig5.axes)
fig5.axes[2].plot(xs, ys)
# Out:
# Figure(432x288)
# Figure(432x288)
# [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]

# %%
# axe
f, axe = plt.subplots()
axe.plot(xs, ys)
axe.set_title('axe title')
axe.set_xlabel('x label')
axe.set_ylabel('Y label')

axe.set_xlim(-10, 55)
# axe.set_ylim(-0.5, 0.75)

# axe.set_xmargin(0.5)
# axe.set_ymargin(0.5)

# axe.margins(0.2)
# axe.margins(x=0.3, y=0.5)

axe.set(xmargin=0.7, ymargin=0.5)

# axe.set_xticks(np.linspace(-10, 55, 3))
# axe.set_xticks([10,15,20], list('abc'))
axe.set_xticks([10,15,20], ['p1','p2','p3'])

f.set_facecolor('green')
f.savefig('test.png')

# %%
import matplotlib.image as mpi

cat_image = mpi.imread('cat.jpg')
print(type(cat_image))
print(cat_image.shape)   # (224, 225, 3)   픽셀 픽셀 3개채널  r g b

_, axe = plt.subplots()
axe.imshow(cat_image)
# Out:
# <class 'numpy.ndarray'>
# (224, 225, 3)
